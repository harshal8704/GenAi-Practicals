# %% [markdown]
# <a href="https://colab.research.google.com/github/harshal8704/GenAi-Practicals/blob/main/GenAI_Prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aim : To perform text pre processing with NLP Techniques.

# %%
sample_dataset = "1.I absolutely LOVE this phone!! Battery lasts 2 days.  2.Worst Product Ever :( Money Wasted !!   3.Delivery was quick, but the packaging was damaged :( :(   4.Excellent camera quality and amazing performance !!"

# %%
# 1.Convert text to lowercase
sample_dataset = sample_dataset.lower()
print(sample_dataset)
# Out:
# 1.i absolutely love this phone!! battery lasts 2 days.  2.worst product ever :( money wasted !!   3.delivery was quick, but the packaging was damaged :( :(   4.excellent camera quality and amazing performance !!

# %%
# 2.Remove Punctuation
import string

sample_dataset = sample_dataset.translate(str.maketrans('', '', string.punctuation))
print(sample_dataset)
# Out:
# 1i absolutely love this phone battery lasts 2 days  2worst product ever  money wasted    3delivery was quick but the packaging was damaged     4excellent camera quality and amazing performance

# %%
# 3.Remove Numbers
import re

sample_dataset = re.sub(r'\d+', '', sample_dataset)
print(sample_dataset)
# Out:
# i absolutely love this phone battery lasts  days  worst product ever  money wasted    delivery was quick but the packaging was damaged     excellent camera quality and amazing performance

# %%
# 4.Remove StopWords
import nltk
nltk.download('stopwords') # Download stopwords corpus
nltk.download('punkt') # Download punkt tokenizer for word_tokenize
nltk.download('punkt_tab') # Download punkt_tab as specifically requested by error

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
words = word_tokenize(sample_dataset) # Tokenize the dataset

# Filter out stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]
sample_dataset = ' '.join(filtered_words)
print(sample_dataset)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# absolutely love phone battery lasts days worst product ever money wasted delivery quick packaging damaged excellent camera quality amazing performance

# %% [markdown]
# ## Apply Preprocessing to a Sample Email for Spam Detection

# %%
# 5. Define a sample email
sample_email = "Subject: Urgent: Your account has been compromised! Click this link now: http://malicious.com/phish123 Get FREE money! Limited time offer! Call 1-800-spam-now. "
print(f"Original Email:\n{sample_email}")
# Out:
# Original Email:
# Subject: Urgent: Your account has been compromised! Click this link now: http://malicious.com/phish123 Get FREE money! Limited time offer! Call 1-800-spam-now.

# %%
# 6. Convert email to lowercase
sample_email = sample_email.lower()
print(f"\nAfter Lowercasing:\n{sample_email}")
# Out:
# After Lowercasing:
# subject: urgent: your account has been compromised! click this link now: http://malicious.com/phish123 get free money! limited time offer! call 1-800-spam-now.

# %%
import string

# 7. Remove Punctuation from email
sample_email = sample_email.translate(str.maketrans('', '', string.punctuation))
print(f"\nAfter Punctuation Removal:\n{sample_email}")
# Out:
# After Punctuation Removal:
# subject urgent your account has been compromised click this link now httpmaliciouscomphish123 get free money limited time offer call 1800spamnow

# %%
import re

# 8. Remove Numbers from email
sample_email = re.sub(r'\d+', '', sample_email)
print(f"\nAfter Number Removal:\n{sample_email}")
# Out:
# After Number Removal:
# subject urgent your account has been compromised click this link now httpmaliciouscomphish get free money limited time offer call spamnow

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Ensure NLTK data is downloaded (if not already)
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

# 9. Remove StopWords from email
stop_words = set(stopwords.words('english'))
email_words = word_tokenize(sample_email) # Tokenize the email

# Filter out stopwords
filtered_email_words = [word for word in email_words if word.lower() not in stop_words]
sample_email_processed = ' '.join(filtered_email_words)
print(f"\nAfter Stopword Removal:\n{sample_email_processed}")
# Out:
# After Stopword Removal:
# subject urgent account compromised click link httpmaliciouscomphish get free money limited time offer call spamnow
